# %%
import pandas as pd

# %%
dfBboxes = pd.read_csv('./luna_bboxlist.csv')
dfDatapath = pd.read_csv('./luna_datapath.csv')

# %%
dfBboxes[dfBboxes['from_subset']==0]
# Out:
#      Unnamed: 0                                           filename  \
# 0             0  1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524...
# 1             1  1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524...
# 2             2  1.3.6.1.4.1.14519.5.2.1.6279.6001.303421828981...
# 3             3  1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686...
# 4             4  1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686...
# ..          ...                                                ...
# 107         107  1.3.6.1.4.1.14519.5.2.1.6279.6001.250863365157...
# 108         108  1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224...
# 109         109  1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224...
# 110         110  1.3.6.1.4.1.14519.5.2.1.6279.6001.832260670372...
# 111         111  1.3.6.1.4.1.14519.5.2.1.6279.6001.832260670372...
#
#                                                   bbox  \
# 0    [85.4213676, 102.70280896, 202.88853569, 13.59...
# ...

# %%
1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.npz

1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493.npz

1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729.npz

1.3.6.1.4.1.14519.5.2.1.6279.6001.303421828981831854739626597495.npz

1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492.npz

1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074.npz

# %%
dfBboxes[dfBboxes['npz_path']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.npz']
# Out:
#    Unnamed: 0                                           filename  \
# 0           0  1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524...
# 1           1  1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524...
#
#                                                 bbox  \
# 0  [85.4213676, 102.70280896, 202.88853569, 13.59...
# 1  [70.6780888, 131.07166564999997, 193.09204143,...
#
#                                             npz_path  from_subset
# 0  ./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.1...            0
# 1  ./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.1...            0

# %%
new_dfBboxes = pd.concat([dfBboxes[dfBboxes['npz_path']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.npz'],
                          dfBboxes[dfBboxes['npz_path']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493.npz'],
                          dfBboxes[dfBboxes['npz_path']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729.npz'],
                          dfBboxes[dfBboxes['npz_path']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.303421828981831854739626597495.npz'],
                          dfBboxes[dfBboxes['npz_path']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492.npz'],
                          dfBboxes[dfBboxes['npz_path']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074.npz']    
],ignore_index=True)

# %%
new_dfBboxes
# Out:
#     Unnamed: 0                                           filename  \
# 0            0  1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524...
# 1            1  1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524...
# 2            3  1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686...
# 3            4  1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686...
# 4            5  1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261...
# 5            6  1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261...
# 6            2  1.3.6.1.4.1.14519.5.2.1.6279.6001.303421828981...
# 7            7  1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896...
# 8           10  1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640...
# 9           11  1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640...
# 10          12  1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640...
#
#                                                  bbox  \
# 0   [85.4213676, 102.70280896, 202.88853569, 13.59...
# 1   [70.6780888, 131.07166564999997, 193.09204143,...
# ...

# %%
new_dfDatapath = pd.concat([dfDatapath[dfDatapath['filePath']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.npz'],
                          dfDatapath[dfDatapath['filePath']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493.npz'],
                          dfDatapath[dfDatapath['filePath']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729.npz'],
                          dfDatapath[dfDatapath['filePath']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.303421828981831854739626597495.npz'],
                          dfDatapath[dfDatapath['filePath']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492.npz'],
                          dfDatapath[dfDatapath['filePath']=='./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074.npz']    
],ignore_index=True)

# %%
new_dfDatapath
# Out:
#                                             filename  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524...
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686...
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261...
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.303421828981...
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896...
# 5  1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640...
#
#                                             filePath
# 0  ./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.1...
# 1  ./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.1...
# 2  ./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.2...
# 3  ./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.3...
# 4  ./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.1...
# 5  ./luna_npy/1.3.6.1.4.1.14519.5.2.1.6279.6001.2...

# %%
new_dfBboxes.to_csv('new_luna_bboxlist.csv')

# %%
new_dfDatapath.to_csv('new_luna_datapath.csv')

# %%
Union[12,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-68678627baec> in <module>
# ----> 1 Union[12,1]
#
# NameError: name 'Union' is not defined

# %%
from typing import Union

# %%
Union[12,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-68678627baec> in <module>
# ----> 1 Union[12,1]
#
# ~/opt/anaconda3/lib/python3.7/typing.py in inner(*args, **kwds)
#     252         except TypeError:
#     253             pass  # All real errors (not unhashable args) are raised below.
# --> 254         return func(*args, **kwds)
#     255     return inner
#     256
#
# ~/opt/anaconda3/lib/python3.7/typing.py in __getitem__(self, parameters)
#     349                 parameters = (parameters,)
#     350             msg = "Union[arg, ...]: each arg must be a type."
# --> 351             parameters = tuple(_type_check(p, msg) for p in parameters)
#     352             parameters = _remove_dups_flatten(parameters)
#     353             if len(parameters) == 1:
#
# ~/opt/anaconda3/lib/python3.7/typing.py in <genexpr>(.0)
# ...

# %%
[].append([1,3])
