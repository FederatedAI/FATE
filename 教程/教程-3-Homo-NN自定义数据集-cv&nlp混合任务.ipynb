# %% [markdown]
# # Homo NN 自定义数据集: 图像+文本特征
#
# 在该版本中 整个nn的架构有很大的调整，nn模块开发了dataset模块，旨在提供数据集和模型的自定义功能，上个教程中，我们介绍了模型自定义，在这个教程中， 我们将会介绍如何进行Dataset的自定义，我们会以一个具有混合类型的数据集为例

# %% [markdown]
# ## 开发一个混合了图片与文本的数据集
#
# 该任务中我们使用flicker 的 image captions数据集，由于原数据集较大，我们将其缩减，位置位于examples/data/flicker_toy_data
#
# 我们粗略的将其分为两类，一类是位于野外的照片，以及对照片的文本描述；另一类是处于城市的照片，以及对照片的文本描述，
# 我们以图片和文本作为特征，开发一个分类模型，第一步，就是开发一个数据集
#
# 首先我们来看看原始数据
#
# ### 原始数据

# %%
import pandas as pd
df_text = pd.read_csv('../examples/data/flicker_toy_data/text.csv')

# %%
df_text
# Out:
#                         id                                               text
# 0    1022454428_b6b660a67b  A man and woman care for an infant along the s...
# 1     103195344_5d2dc613a3  A man sitting in front of a metal sculpture in...
# 2    1055753357_4fa3d8d693  Two construction workers take a seat on a stee...
# 3    1124448967_2221af8dc5    Man relaxing in a folding chair on the street .
# 4    1131804997_177c3c0640  Two men with backpacks are sitting on cardboar...
# ..                     ...                                                ...
# 210    78984436_ad96eaa802  Two German shepherd dogs are running with an o...
# 211    84713990_d3f3cef78b  Several people are rafting down a choppy river...
# 212    90011335_cfdf9674c2  A white boat on glassy water with mountains in...
# 213    96973080_783e375945                      A dog runs through the snow .
# 214    96985174_31d4c6f06d           The person is walking in the mountains .
#
# [215 rows x 2 columns]

# %%
# 文件夹下有两类图片
import os
os.listdir('../examples/data/flicker_toy_data/flicker/images/')
# Out:
# ['wild', 'city']

# %%
# 每个图片都有其id，对应了df_text里的每一个id
os.listdir('../examples/data/flicker_toy_data/flicker/images/city')
# Out:
# ['1332492622_8c66992b62.jpg',
#  '241345639_1556a883b1.jpg',
#  '47871819_db55ac4699.jpg',
#  '617038406_4092ee91dd.jpg',
#  '616045808_0286d0574b.jpg',
#  '1055753357_4fa3d8d693.jpg',
#  '211295363_49010ca38d.jpg',
#  '635444010_bd81c89ab7.jpg',
#  '309771854_952aabe3cc.jpg',
#  '1167908324_8caab45e15.jpg',
#  '247619370_a01fb21dd3.jpg',
#  '241345323_f53eb5eec4.jpg',
#  '191003285_edd8d0cf58.jpg',
#  '1143373711_2e90b7b799.jpg',
#  '615916000_5044047d71.jpg',
#  '241345656_861aacefde.jpg',
#  '241346105_c1c860db0d.jpg',
#  '489134459_1b3f46fc03.jpg',
#  '1355945307_f9e01a9a05.jpg',
#  '1984936420_3f3102132b.jpg',
#  '241345811_46b5f157d4.jpg',
#  '1342766791_1e72f92455.jpg',
#  '297285273_688e44c014.jpg',
#  '1346051107_9cdc14e070.jpg',
#  '191003284_1025b0fb7d.jpg',
#  '1467533293_a2656cc000.jpg',
#  '1131804997_177c3c0640.jpg',
#  '241345905_5826a72da1.jpg',
#  '1022454428_b6b660a67b.jpg',
#  '1426014905_da60d72957.jpg',
#  '317641829_ab2607a6c0.jpg',
#  '2073174497_18b779999c.jpg',
#  '535249787_0fcaa613a0.jpg',
#  '2073964624_52da3a0fc4.jpg',
#  '1138784872_69ade3f2ab.jpg',
#  '241345522_c3c266a02a.jpg',
#  '381514859_b40418d9c3.jpg',
#  '44129946_9eeb385d77.jpg',
#  '241345427_ece0d186c2.jpg',
#  '241345446_2e47ae8ddc.jpg',
#  '633456174_b768c1d6cd.jpg',
#  '848180689_d67a1361ce.jpg',
#  '241345770_9f8aa6723c.jpg',
#  '1468389504_c724bdcad0.jpg',
#  '1463638541_c02cfa04dc.jpg',
#  '1342780478_bacc32344d.jpg',
#  '241345844_69e1c22464.jpg',
#  '1936215201_d03a75cbba.jpg',
#  '1461653394_8ab96aae63.jpg',
#  '191003283_992257f835.jpg',
#  '244867897_d00369a779.jpg',
#  '1143882946_1898d2eeb9.jpg',
#  '823697339_aadbeef495.jpg',
#  '534875358_6ea30d3091.jpg',
#  '325576658_59f68bdbd6.jpg',
#  '1321949151_77b77b4617.jpg',
#  '461019788_bc0993dabd.jpg',
#  '42637987_866635edf6.jpg',
#  '613900608_2e49415772.jpg',
#  '241346260_f50d57b517.jpg',
#  '310260324_7f941814bc.jpg',
#  '2056930414_d2b0f1395a.jpg',
#  '1144288288_e5c9558b6a.jpg',
#  '119534510_d52b3781a3.jpg',
#  '394463341_5311c53783.jpg',
#  '1329832826_432538d331.jpg',
#  '1427391496_ea512cbe7f.jpg',
#  '241345942_ea76966542.jpg',
#  '310728631_155c3bbeea.jpg',
#  '241345864_138471c9ea.jpg',
#  '241346146_f27759296d.jpg',
#  '616177206_0e16c33f6b.jpg',
#  '241346215_037e18403a.jpg',
#  '1321723162_9d4c78b8af.jpg',
#  '380590140_25b9889772.jpg',
#  '241346317_be3f07bd2e.jpg',
#  '1142847777_2a0c1c2551.jpg',
#  '972381743_5677b420ab.jpg',
#  '27782020_4dab210360.jpg',
#  '1991806812_065f747689.jpg',
#  '307994435_592f933a6d.jpg',
#  '103195344_5d2dc613a3.jpg',
#  '241345533_99c731403a.jpg',
#  '1805990081_da9cefe3a5.jpg',
#  '241345596_91e0e2daf5.jpg',
#  '534886684_a6c9f40fa1.jpg',
#  '531197115_2be4d5034b.jpg',
#  '824123145_59243e504e.jpg',
#  '241345981_1ef4f8109c.jpg',
#  '236474697_0c73dd5d8b.jpg',
#  '523327429_af093fc7cf.jpg',
#  '2094323311_27d58b1513.jpg',
#  '1124448967_2221af8dc5.jpg',
#  '1387443857_602ab6f9bf.jpg',
#  '1424775129_ffea9c13ab.jpg',
#  '241345721_3f3724a7fc.jpg',
#  '42637986_135a9786a6.jpg',
#  '1461667284_041c8a2475.jpg',
#  '1148238960_f8cacec2fc.jpg',
#  '47870024_73a4481f7d.jpg',
#  '894928353_002a3d5f06.jpg',
#  '2088460083_42ee8a595a.jpg',
#  '1149179852_acad4d7300.jpg',
#  '310213587_778fe8fb5b.jpg',
#  '309238565_2d5d8dc8bf.jpg',
#  '2180356743_b3a3c9a7f6.jpg',
#  '1332208215_fa824f6659.jpg']

# %% [markdown]
# ### Dataset
#
# Fate中nn.dataset下提供了一个Dataset基类，其要求实现的接口除了load接口外，与Pytorch Dataset完全一致。基于Dataset实现的数据集类，将其更新到nn.dataset模块中，FATE在运行时便可根据参数导入您自定义的数据集，进行训练，此处，我们实现一个MixFeatureDataset
#
# 这里使用便捷的jupyter notebook接口将开发好的数据集代码其更新到nn.dataset模块中

# %%
from pipeline.component.homo_nn import save_to_fate # 更新接口

# %%
# %%save_to_fate dataset mix_feature_ds.py
# import torch as t
# import pandas as pd
# from federatedml.nn.dataset.base import Dataset
# from torchvision.datasets import ImageFolder
# from torchvision import transforms
# from transformers import BertTokenizerFast
#
# class MixFeatureDataset(Dataset):
#
#     def __init__(self, output_image_size):
#         super(MixFeatureDataset, self).__init__() # 记得这个
#         self.output_image_size = output_image_size
#         self.image_folder = None
#         self.text = None
#         self.word_idx = None
#         self.vocab_size = 0
#         self.sample_ids = None
#
#     # 需要实现的接口 load, load接受一个参数path, 算法运行时将会把path传给这个接口
#     def load(self, path):
#         # 处理图像数据集
#         transformer = transforms.Compose([transforms.CenterCrop(size=self.output_image_size), transforms.ToTensor()])
#         self.image_folder = ImageFolder(root=path+'/flicker/images', transform=transformer)
#
#         # 处理文本数据集，将其符号化（tokenize)
#         import os
#         os.environ["TOKENIZERS_PARALLELISM"] = "false" # avoid tokenizer problem
#
#         self.text = pd.read_csv(path+'/text.csv')
#         tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased') # 用bert tokenizer
#         text_list = list(self.text.text)
#         self.word_idx = tokenizer(text_list, padding=True, return_tensors='pt',
#                                   truncation=True, max_length=20)['input_ids']
#         self.vocab_size = tokenizer.vocab_size
#
#         # 保证image数据集图片的id能与文本的id对应上
#         img_ids = [i[0].split('/')[-1].replace('.jpg', '') for i in self.image_folder.imgs]
#         text_ids = list(self.text.id)
#         assert img_ids == text_ids
#         print('id match!')
#         self.sample_ids = text_ids
#
#
#     # 需要实现的接口1 len
#     def __len__(self):
#         return len(self.image_folder)
#
#     # 需要实现的接口2 getitem, 返回（数据，label)
#     def __getitem__(self, idx):
#         img, label = self.image_folder[idx]
#         text = self.word_idx[idx]
#         return (img, text), t.tensor(label).type(t.float32)
#
#     # 此接口可选，如果不实现，FATE将拿不到sample id，便自动生成
#     def get_sample_ids(self,):
#         return self.sample_ids

# %%
ds = MixFeatureDataset((224, 224)) # 图片规范的尺寸
ds.load('../examples/data/flicker_toy_data/')
# Out:
# id match!

# %%
ds[0]
# Out:
# ((tensor([[[0.5059, 0.5176, 0.5137,  ..., 0.4941, 0.5020, 0.5059],
#            [0.4980, 0.5020, 0.4980,  ..., 0.4824, 0.5020, 0.5059],
#            [0.5059, 0.4863, 0.4902,  ..., 0.4980, 0.4980, 0.5137],
#            ...,
#            [0.7843, 0.7922, 0.7529,  ..., 0.1412, 0.2078, 0.2196],
#            [0.9922, 0.9922, 0.9647,  ..., 0.1176, 0.0941, 0.1333],
#            [0.9961, 0.9922, 1.0000,  ..., 0.1647, 0.1294, 0.1373]],
#
#           [[0.5765, 0.5882, 0.5843,  ..., 0.5490, 0.5569, 0.5608],
#            [0.5686, 0.5804, 0.5765,  ..., 0.5490, 0.5529, 0.5529],
#            [0.5608, 0.5569, 0.5647,  ..., 0.5569, 0.5490, 0.5529],
#            ...,
#            [0.7961, 0.8039, 0.7490,  ..., 0.1373, 0.1882, 0.2000],
#            [0.9961, 0.9961, 0.9608,  ..., 0.1137, 0.1137, 0.1529],
#            [0.9922, 0.9922, 1.0000,  ..., 0.1608, 0.1059, 0.1216]],
#
#           [[0.6235, 0.6353, 0.6314,  ..., 0.5922, 0.6000, 0.6118],
#            [0.6078, 0.6235, 0.6196,  ..., 0.5804, 0.5882, 0.6000],
#            [0.6039, 0.6118, 0.6196,  ..., 0.5843, 0.5843, 0.6000],
#            ...,
#            [0.5882, 0.5961, 0.5686,  ..., 0.1216, 0.1765, 0.1882],
#            [0.7294, 0.7373, 0.7373,  ..., 0.0980, 0.0980, 0.1294],
#            [0.8745, 0.8431, 0.8627,  ..., 0.1451, 0.1059, 0.1176]]]),
#   tensor([  101,  1037,  2158,  1998,  2450,  2729,  2005,  2019, 10527,  2247,
#            1996,  2217,  1997,  1037,  2303,  1997,  2300,  1012,   102,     0])),
#  tensor(0.))

# %% [markdown]
# ### 测试一下能不能用

# %%
from torch.utils.data import DataLoader

for i in DataLoader(ds, batch_size=2):
    break

# %%
i
# Out:
# [[tensor([[[[0.5059, 0.5176, 0.5137,  ..., 0.4941, 0.5020, 0.5059],
#             [0.4980, 0.5020, 0.4980,  ..., 0.4824, 0.5020, 0.5059],
#             [0.5059, 0.4863, 0.4902,  ..., 0.4980, 0.4980, 0.5137],
#             ...,
#             [0.7843, 0.7922, 0.7529,  ..., 0.1412, 0.2078, 0.2196],
#             [0.9922, 0.9922, 0.9647,  ..., 0.1176, 0.0941, 0.1333],
#             [0.9961, 0.9922, 1.0000,  ..., 0.1647, 0.1294, 0.1373]],
#
#            [[0.5765, 0.5882, 0.5843,  ..., 0.5490, 0.5569, 0.5608],
#             [0.5686, 0.5804, 0.5765,  ..., 0.5490, 0.5529, 0.5529],
#             [0.5608, 0.5569, 0.5647,  ..., 0.5569, 0.5490, 0.5529],
#             ...,
#             [0.7961, 0.8039, 0.7490,  ..., 0.1373, 0.1882, 0.2000],
#             [0.9961, 0.9961, 0.9608,  ..., 0.1137, 0.1137, 0.1529],
#             [0.9922, 0.9922, 1.0000,  ..., 0.1608, 0.1059, 0.1216]],
#
#            [[0.6235, 0.6353, 0.6314,  ..., 0.5922, 0.6000, 0.6118],
#             [0.6078, 0.6235, 0.6196,  ..., 0.5804, 0.5882, 0.6000],
#             [0.6039, 0.6118, 0.6196,  ..., 0.5843, 0.5843, 0.6000],
#             ...,
#             [0.5882, 0.5961, 0.5686,  ..., 0.1216, 0.1765, 0.1882],
#             [0.7294, 0.7373, 0.7373,  ..., 0.0980, 0.0980, 0.1294],
#             [0.8745, 0.8431, 0.8627,  ..., 0.1451, 0.1059, 0.1176]]],
#
#
#           [[[0.3804, 0.3882, 0.4039,  ..., 0.3961, 0.3804, 0.3843],
#             [0.3765, 0.3843, 0.3961,  ..., 0.3882, 0.3765, 0.3765],
#             [0.3843, 0.3961, 0.4078,  ..., 0.3686, 0.3765, 0.3765],
#             ...,
#             [0.8275, 0.9843, 0.3451,  ..., 0.0863, 0.0824, 0.0824],
#             [0.8353, 0.9569, 0.3137,  ..., 0.0588, 0.0549, 0.0510],
#             [0.8549, 0.9647, 0.2941,  ..., 0.0549, 0.0588, 0.0588]],
#
#            [[0.4353, 0.4431, 0.4627,  ..., 0.4706, 0.4549, 0.4588],
#             [0.4314, 0.4392, 0.4549,  ..., 0.4627, 0.4510, 0.4510],
#             [0.4392, 0.4549, 0.4667,  ..., 0.4353, 0.4431, 0.4471],
#             ...,
#             [0.8706, 0.9922, 0.4196,  ..., 0.0706, 0.0667, 0.0667],
#             [0.8980, 0.9843, 0.4000,  ..., 0.0588, 0.0549, 0.0510],
#             [0.9176, 0.9922, 0.3804,  ..., 0.0549, 0.0588, 0.0588]],
#
#            [[0.3373, 0.3451, 0.3725,  ..., 0.3843, 0.3765, 0.3804],
#             [0.3333, 0.3490, 0.3647,  ..., 0.3843, 0.3725, 0.3647],
#             [0.3412, 0.3647, 0.3765,  ..., 0.3647, 0.3686, 0.3608],
#             ...,
#             [0.7451, 0.9373, 0.4118,  ..., 0.0667, 0.0549, 0.0549],
#             [0.7569, 0.9216, 0.3882,  ..., 0.0588, 0.0549, 0.0510],
#             [0.7765, 0.9294, 0.3725,  ..., 0.0549, 0.0588, 0.0588]]]]),
#   tensor([[  101,  1037,  2158,  1998,  2450,  2729,  2005,  2019, 10527,  2247,
#             1996,  2217,  1997,  1037,  2303,  1997,  2300,  1012,   102,     0],
#           [  101,  1037,  2158,  3564,  1999,  2392,  1997,  1037,  3384,  6743,
#             1999,  2392,  1997,  1037,  2311,  1012,   102,     0,     0,     0]])],
#  tensor([0., 0.])]

# %% [markdown]
# nice! 至此我们已经有一个数据集了，我们再为它开发对应的模型，然后进行本地测试，如果可以跑通，就可以提交为联邦任务了 注意，这里为了演示方便 我们只使用一个数据集，在实际使用中，你可以基于某一方的数据集进行开发, 本地验证，然后联邦任务时再使用全部的数据

# %% [markdown]
# ## 自定义一个模型
#
# 这里定义一个可以同时处理图像和文本的模型，保存到nn.model_zoo下, 模块名称为flicker_classifier

# %%
# %%save_to_fate model flicker_classifier.py
# import torch as t
# from torch import nn
#
# class FlickerClassifier(nn.Module):
#
#     def __init__(self, vocab_size,word_embed_size=8):
#         super(FlickerClassifier, self).__init__()
#
#         # 图像部分
#         self.cv_seq = t.nn.Sequential(
#             nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5),
#             nn.MaxPool2d(kernel_size=3),
#             nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3),
#             nn.AvgPool2d(kernel_size=5)
#         )
#         self.fc = t.nn.Sequential(
#             nn.Linear(1176, 32),
#             nn.ReLU(),
#             nn.Linear(32, 8)
#         )
#         # NLP部分
#         self.word_embedding = nn.Embedding(num_embeddings=vocab_size, embedding_dim=word_embed_size)
#         self.lstm_seq = nn.LSTM(input_size=word_embed_size, hidden_size=word_embed_size, batch_first=True)
#         # 分类器
#         self.classifier_seq = nn.Sequential(
#             nn.ReLU(),
#             nn.Linear(word_embed_size + 8, 1),
#             nn.Sigmoid()
#         )
#
#     def forward(self, x):
#         image_feat = x[0]
#         word_feat = x[1]
#
#         image_feat = self.fc(self.cv_seq(image_feat).flatten(start_dim=1))
#         word_feat, _ = self.lstm_seq(self.word_embedding(x[1]))
#         word_feat = word_feat.sum(dim=1)
#         return self.classifier_seq(t.cat([image_feat, word_feat], axis=1)).flatten()

# %%
model = FlickerClassifier(ds.vocab_size, 8)

# %%
model(i[0])
# Out:
# tensor([0.6456, 0.7330], grad_fn=<ReshapeAliasBackward0>)

# %% [markdown]
# ## 本地验证
#
# 我们本地测试下这一套（数据集+模型）能否跑通，本地验证情况下会略去联邦聚合的部分

# %%
import torch as t
from federatedml.nn.backend.utils.common import global_seed
from federatedml.nn.homo.trainer.fedavg_trainer import FedAVGTrainer

global_seed(100)
ds = MixFeatureDataset((224, 224)) # 图片规范的尺寸
ds.load('../examples/data/flicker_toy_data/')
model = FlickerClassifier(ds.vocab_size, 8)
optimizer = t.optim.Adam(model.parameters(), lr=0.01)
loss = t.nn.BCELoss()
trainer = FedAVGTrainer(epochs=5, batch_size=64, data_loader_worker=4)
trainer.local_mode()  # !!!
trainer.set_model(model)
# Out:
# id match!

# %%
trainer.train(ds, optimizer=optimizer, loss=loss)
# Out:
# epoch is 0
# epoch loss is 0.846086848059366
# epoch is 1
# epoch loss is 0.7933921104253725
# epoch is 2
# epoch loss is 0.7724235889523529
# epoch is 3
# epoch loss is 0.7441925581111465
# epoch is 4
# epoch loss is 0.7270668562068495

# %% [markdown]
# ## 提交Homo-NN
#
# 完成了本地验证，确认可以跑通后，我们可以通过pipeline提交模型了

# %%
import torch as t
from torch import nn
from pipeline import fate_torch_hook
from pipeline.component import HomoNN
from pipeline.backend.pipeline import PipeLine
from pipeline.component import Reader, Evaluation, DataTransform
from pipeline.interface import Data, Model

fate_torch_hook(t)


import os
# 绑定地址到fate name&namespace
fate_project_path = os.path.abspath('../')
host_0 = 10000
host_1 = 9999
pipeline = PipeLine().set_initiator(role='host', party_id=host_0).set_roles(host=[host_0, host_1],
                                                                            arbiter=[host_0])
data_0 = {"name": "flicker", "namespace": "experiment"}
# 为方便，本示例中两个client使用同一份数据集
data_path = fate_project_path + '/examples/data/flicker_toy_data'
pipeline.bind_table(name=data_0['name'], namespace=data_0['namespace'], path=data_path)
pipeline.bind_table(name=data_0['name'], namespace=data_0['namespace'], path=data_path)
# Out:
# {'namespace': 'experiment', 'table_name': 'flicker'}

# %%
# 定义reader
reader_0 = Reader(name="reader_0")
reader_0.get_party_instance(role='host', party_id=host_0).component_param(table=data_0)
reader_0.get_party_instance(role='host', party_id=host_1).component_param(table=data_0)

# %%
from pipeline.component.homo_nn import DatasetParam, TrainerParam  # 数据集的接口

model = t.nn.Sequential(
    t.nn.CustModel(module_name='flicker_classifier', class_name='FlickerClassifier' ,vocab_size=ds.vocab_size, word_embed_size=8) 
)

nn_component = HomoNN(name='nn_0',
                      model=model, # 模型
                      loss=t.nn.BCELoss(),
                      optimizer=t.optim.Adam(model.parameters(), lr=0.01),
                      dataset=DatasetParam(dataset_name='mix_feature_ds', output_image_size=(224, 224)),  # 使用自定义的dataset
                      trainer=TrainerParam(trainer_name='fedavg_trainer', epochs=5, batch_size=64, data_loader_worker=4, validation_freqs=1,
                                           secure_aggregate=False),
                      torch_seed=100 # 全局随机种子
                      )

# %%
# 添加组件到pipeline，定义数据IO关系，提交即可
pipeline.add_component(reader_0)
pipeline.add_component(nn_component, data=Data(train_data=reader_0.output.data))
pipeline.add_component(Evaluation(name='eval_0', eval_type='binary'), data=Data(data=nn_component.output.data))

# %%
pipeline.compile()
pipeline.fit()
# Out:
# 2022-11-11 12:32:24.100 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202211111232233316510
#
# 2022-11-11 12:32:24.112 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# m2022-11-11 12:32:25.171 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2022-11-11 12:32:25.172 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:01
# 2022-11-11 12:32:26.206 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:02
# 2022-11-11 12:32:27.243 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:03
# 2022-11-11 12:32:28.277 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:04
# 2022-11-11 12:32:29.313 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:05
# 2022-11-11 12:32:30.345 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:06
# 2022-11-11 12:32:31.377 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:07
# m2022-11-11 12:32:32.422 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2022-11-11 12:32:32.431 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:08
# 2022-11-11 12:32:33.464 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:09
# 2022-11-11 12:32:34.823 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:10
# 2022-11-11 12:32:35.857 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:11
# 2022-11-11 12:32:36.889 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:12
# 2022-11-11 12:32:37.973 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:13
# 2022-11-11 12:32:39.138 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:15
# 2022-11-11 12:32:40.169 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:16
# 2022-11-11 12:32:41.207 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:17
# 2022-11-11 12:32:42.239 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:18
# 2022-11-11 12:32:43.786 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:19
# 2022-11-11 12:32:44.867 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:20
# 2022-11-11 12:32:46.015 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:21
# 2022-11-11 12:32:47.069 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:22
# 2022-11-11 12:32:48.164 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:24
# 2022-11-11 12:32:49.243 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:25
# 2022-11-11 12:32:50.366 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:26
# 2022-11-11 12:32:51.485 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:27
# 2022-11-11 12:32:52.665 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:28
# 2022-11-11 12:32:53.768 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:29
# 2022-11-11 12:32:54.870 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:30
# 2022-11-11 12:32:56.053 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:31
# 2022-11-11 12:32:57.169 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:33
# 2022-11-11 12:32:58.332 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:34
# 2022-11-11 12:32:59.454 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:35
# 2022-11-11 12:33:00.569 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:36
# 2022-11-11 12:33:01.693 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:37
# 2022-11-11 12:33:02.803 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:38
# 2022-11-11 12:33:03.942 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:39
# 2022-11-11 12:33:05.059 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:40
# 2022-11-11 12:33:06.165 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:42
# 2022-11-11 12:33:07.310 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:43
# 2022-11-11 12:33:08.498 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:44
# 2022-11-11 12:33:09.619 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:45
# 2022-11-11 12:33:10.715 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:46
# 2022-11-11 12:33:11.834 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:47
# 2022-11-11 12:33:12.979 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:48
# 2022-11-11 12:33:14.155 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:50
# 2022-11-11 12:33:15.262 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:51
# 2022-11-11 12:33:16.428 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:52
# 2022-11-11 12:33:17.535 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:53
# 2022-11-11 12:33:18.670 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:54
# 2022-11-11 12:33:19.818 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:55
# 2022-11-11 12:33:20.940 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:56
# 2022-11-11 12:33:22.063 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:57
# 2022-11-11 12:33:23.183 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:00:59
# 2022-11-11 12:33:24.338 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:00
# 2022-11-11 12:33:25.449 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:01
# 2022-11-11 12:33:26.613 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:02
# 2022-11-11 12:33:27.760 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:03
# 2022-11-11 12:33:28.905 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:04
# 2022-11-11 12:33:29.990 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:05
# 2022-11-11 12:33:31.135 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:07
# 2022-11-11 12:33:32.248 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:08
# 2022-11-11 12:33:33.427 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:09
# 2022-11-11 12:33:34.544 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:10
# 2022-11-11 12:33:35.629 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:11
# 2022-11-11 12:33:36.779 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:12
# 2022-11-11 12:33:37.915 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:13
# 2022-11-11 12:33:39.136 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:15
# 2022-11-11 12:33:40.263 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:16
# 2022-11-11 12:33:41.410 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:17
# 2022-11-11 12:33:42.535 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:18
# 2022-11-11 12:33:43.618 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:19
# 2022-11-11 12:33:44.798 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:20
# 2022-11-11 12:33:45.914 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:21
# 2022-11-11 12:33:47.043 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:22
# 2022-11-11 12:33:48.191 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:24
# 2022-11-11 12:33:49.375 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:25
# 2022-11-11 12:33:50.540 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:26
# 2022-11-11 12:33:51.727 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:27
# 2022-11-11 12:33:52.834 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:28
# 2022-11-11 12:33:53.943 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:29
# 2022-11-11 12:33:55.146 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:31
# 2022-11-11 12:33:56.258 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:32
# 2022-11-11 12:33:57.332 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:33
# 2022-11-11 12:33:58.493 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:34
# 2022-11-11 12:33:59.679 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:35
# 2022-11-11 12:34:00.786 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:36
# 2022-11-11 12:34:01.941 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:37
# 2022-11-11 12:34:03.153 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:39
# 2022-11-11 12:34:04.349 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:40
# 2022-11-11 12:34:05.545 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:41
# 2022-11-11 12:34:06.696 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:42
# 2022-11-11 12:34:07.851 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:43
# 2022-11-11 12:34:08.996 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:44
# 2022-11-11 12:34:10.159 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:46
# 2022-11-11 12:34:11.262 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:47
# 2022-11-11 12:34:12.392 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:48
# 2022-11-11 12:34:13.545 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:49
# 2022-11-11 12:34:14.653 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:50
# 2022-11-11 12:34:15.788 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:51
# 2022-11-11 12:34:16.882 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:52
# 2022-11-11 12:34:17.988 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:53
# 2022-11-11 12:34:19.074 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:54
# 2022-11-11 12:34:20.199 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:56
# 2022-11-11 12:34:21.386 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:57
# 2022-11-11 12:34:22.538 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:58
# 2022-11-11 12:34:23.715 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:01:59
# 2022-11-11 12:34:24.885 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:00
# 2022-11-11 12:34:25.951 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:01
# 2022-11-11 12:34:27.168 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:03
# 2022-11-11 12:34:28.287 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:04
# 2022-11-11 12:34:29.450 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:05
# 2022-11-11 12:34:30.575 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:06
# 2022-11-11 12:34:31.713 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:07
# 2022-11-11 12:34:32.900 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:08
# 2022-11-11 12:34:34.027 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:09
# 2022-11-11 12:34:35.114 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:11
# 2022-11-11 12:34:36.246 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:12
# 2022-11-11 12:34:37.362 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:13
# 2022-11-11 12:34:38.480 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:14
# 2022-11-11 12:34:39.617 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:15
# 2022-11-11 12:34:40.716 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:16
# 2022-11-11 12:34:41.860 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:17
# 2022-11-11 12:34:43.040 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:18
# 2022-11-11 12:34:44.119 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:20
# 2022-11-11 12:34:45.329 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:21
# 2022-11-11 12:34:46.511 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:22
# 2022-11-11 12:34:47.655 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:23
# 2022-11-11 12:34:48.743 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:24
# 2022-11-11 12:34:49.922 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:25
# 2022-11-11 12:34:51.138 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:27
# 2022-11-11 12:34:52.282 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:28
# 2022-11-11 12:34:53.449 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:29
# 2022-11-11 12:34:54.624 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:30
# 2022-11-11 12:34:55.782 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:31
# 2022-11-11 12:34:56.957 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:32
# 2022-11-11 12:34:58.064 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:33
# 2022-11-11 12:34:59.165 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:35
# 2022-11-11 12:35:00.361 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:36
# 2022-11-11 12:35:01.465 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:37
# 2022-11-11 12:35:02.528 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:38
# 2022-11-11 12:35:03.699 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:39
# 2022-11-11 12:35:04.823 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:40
# 2022-11-11 12:35:05.890 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:41
# 2022-11-11 12:35:07.056 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:42
# 2022-11-11 12:35:08.222 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:44
# 2022-11-11 12:35:09.546 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:45
# 2022-11-11 12:35:10.676 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:46
# 2022-11-11 12:35:11.821 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:47
# 2022-11-11 12:35:12.987 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:48
# 2022-11-11 12:35:14.100 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:50
# 2022-11-11 12:35:15.278 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:51
# 2022-11-11 12:35:16.388 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:52
# 2022-11-11 12:35:17.569 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:53
# 2022-11-11 12:35:18.683 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:54
# 2022-11-11 12:35:19.819 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:55
# 2022-11-11 12:35:20.948 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:56
# 2022-11-11 12:35:22.097 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:57
# 2022-11-11 12:35:23.199 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:02:59
# 2022-11-11 12:35:24.306 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:00
# 2022-11-11 12:35:25.451 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:01
# 2022-11-11 12:35:26.574 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:02
# 2022-11-11 12:35:27.876 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:03
# 2022-11-11 12:35:29.061 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:04
# 2022-11-11 12:35:30.252 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:06
# 2022-11-11 12:35:31.470 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:07
# 2022-11-11 12:35:32.583 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:08
# 2022-11-11 12:35:33.744 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:09
# 2022-11-11 12:35:34.877 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:10
# 2022-11-11 12:35:36.030 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:11
# 2022-11-11 12:35:37.159 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:13
# 2022-11-11 12:35:38.314 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:14
# 2022-11-11 12:35:39.492 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:15
# 2022-11-11 12:35:40.666 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component nn_0, time elapse: 0:03:16

# %% [markdown]
# 完成训练！你可以在fateboard中查看结果, 或者:

# %%
pipeline.get_component('nn_0').get_output_data()
# Out:
#                         id label predict_result        predict_score  \
# 0        667626_18933d713e   1.0              0   0.3941565454006195
# 1       3637013_c675de7705   1.0              1   0.5649510622024536
# 2      10815824_2997e03d76   1.0              1    0.575126051902771
# 3      17273391_55cfc7d3d4   1.0              1   0.6380451321601868
# 4      19212715_20476497a3   1.0              0  0.42395642399787903
# ..                     ...   ...            ...                  ...
# 210  3693961165_9d6c333d5b   1.0              1   0.5886315107345581
# 211  3715559023_70c41b31c7   1.0              1   0.5360317230224609
# 212  3719461451_07de35af3a   1.0              1   0.5874216556549072
# 213  3745451546_fc8ec70cbd   1.0              1   0.5361397862434387
# 214  3747543364_bf5b548527   1.0              1   0.6401607990264893
#
#                                         predict_detail   type
# 0    {'0': 0.6058434545993805, '1': 0.3941565454006...  train
# 1    {'0': 0.4350489377975464, '1': 0.5649510622024...  train
# 2     {'0': 0.424873948097229, '1': 0.575126051902771}  train
# 3    {'0': 0.36195486783981323, '1': 0.638045132160...  train
# 4    {'0': 0.576043576002121, '1': 0.42395642399787...  train
# ..                                                 ...    ...
# 210  {'0': 0.4113684892654419, '1': 0.5886315107345...  train
# 211  {'0': 0.46396827697753906, '1': 0.536031723022...  train
# 212  {'0': 0.4125783443450928, '1': 0.5874216556549...  train
# 213  {'0': 0.4638602137565613, '1': 0.5361397862434...  train
# 214  {'0': 0.35983920097351074, '1': 0.640160799026...  train
#
# [215 rows x 6 columns]
